# %% [markdown]
# # Data Visualization Using Pandas
#
# This Jupyter notebook contains some plots using the Pandas library. However, plotting with Seaborn and Matplotlib are most recommended.
#
# Thanks to https://sites.google.com/site/ownscratchpad/datascience/pandas-built-in-data-visualization

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv('df1.csv', index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2.csv')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %% [markdown]
# # Quick Summary
#
# 1. hist()
# 2. plot(kind='hist')
# 3. plot.hist()
# 4. plot.area()
# 5. plot.bar()
# 6. plot.scatter()
# 7. plot.box()
# 8. plot.hexbin()
# 9. plot.kde()
# 10. plot.density()

# %%
df1['A'].hist()

# %%
df1['A'].hist(bins=30)

# %% [markdown]
# If we import the **Seaborn** library, the **Pandas** plots will we even more beautiful.

# %%
import seaborn as sns
df1['A'].plot(kind='hist')

# %%
df1['A'].plot(kind='hist', bins=30)

# %%
df1['A'].plot.hist()

# %%
df2.plot.area()

# %%
df2.plot.area(alpha=0.4)

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df1['A'].plot.hist(bins=40)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.scatter(x='A', y='B')

# %%
df1.plot.scatter(x='A', y='B', c='C')

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %%
df1.plot.scatter(x='A', y='B', s=df1['C'])
# Out:
# C:\Users\balajiam\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# The warning is handled in the cell below.

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*100)

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a', 'b'])

# %%
df.head()
# Out:
#           a         b
# 0 -0.154417  0.211702
# 1 -0.880552  2.204366
# 2 -0.086744 -1.768832
# 3 -1.065055 -0.279701
# 4 -0.489352 -0.223479

# %%
df.plot.hexbin(x='a', y='b')

# %%
df.plot.hexbin(x='a', y='b', gridsize=20)

# %%
df2['a'].plot.kde()

# %%
df2['a'].plot.density()

# %%
df2.plot.density()
